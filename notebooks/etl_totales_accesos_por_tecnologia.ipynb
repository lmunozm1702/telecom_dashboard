# %% [markdown]
# ## Load libraries

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
sys.path.append("../libs")
sys.path.append("../")
from definitions import ROOT_DIR
import utils as utils

# Set pandas options
# Not use scientific notation and use two decimal places and use comma as thousand separator
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # ETL

# %% [markdown]
# ## 1. Load dataset

# %%
# Load dataset from data_files/internet.xlsx - sheet: 'Ingresos '
df = utils.get_xls_sheet_data('/data_files/internet.xlsx', 'Totales Accesos Por Tecnología')
df.style.format(thousands=',')
# Out:
# <style type="text/css">
# </style>
# <table id="T_f6824">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6824_level0_col0" class="col_heading level0 col0" >Año</th>
#       <th id="T_f6824_level0_col1" class="col_heading level0 col1" >Trimestre</th>
#       <th id="T_f6824_level0_col2" class="col_heading level0 col2" >ADSL</th>
#       <th id="T_f6824_level0_col3" class="col_heading level0 col3" >Cablemodem</th>
#       <th id="T_f6824_level0_col4" class="col_heading level0 col4" >Fibra óptica</th>
#       <th id="T_f6824_level0_col5" class="col_heading level0 col5" >Wireless</th>
#       <th id="T_f6824_level0_col6" class="col_heading level0 col6" >Otros</th>
#       <th id="T_f6824_level0_col7" class="col_heading level0 col7" >Total</th>
#       <th id="T_f6824_level0_col8" class="col_heading level0 col8" >Periodo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6824_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f6824_row0_col0" class="data row0 col0" >2,024</td>
#       <td id="T_f6824_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_f6824_row0_col2" class="data row0 col2" >733,491</td>
#       <td id="T_f6824_row0_col3" class="data row0 col3" >5,867,504</td>
#       <td id="T_f6824_row0_col4" class="data row0 col4" >4,169,958</td>
#       <td id="T_f6824_row0_col5" class="data row0 col5" >593,197</td>
#       <td id="T_f6824_row0_col6" class="data row0 col6" >191,957</td>
#       <td id="T_f6824_row0_col7" class="data row0 col7" >11,556,107</td>
#       <td id="T_f6824_row0_col8" class="data row0 col8" >Abr-Jun 2024</td>
#     </tr>
#     <tr>
#       <th id="T_f6824_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f6824_row1_col0" class="data row1 col0" >2,024</td>
#       <td id="T_f6824_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_f6824_row1_col2" class="data row1 col2" >774,475</td>
#       <td id="T_f6824_row1_col3" class="data row1 col3" >5,986,957</td>
#       <td id="T_f6824_row1_col4" class="data row1 col4" >4,015,101</td>
#       <td id="T_f6824_row1_col5" class="data row1 col5" >598,682</td>
#       <td id="T_f6824_row1_col6" class="data row1 col6" >257,941</td>
#       <td id="T_f6824_row1_col7" class="data row1 col7" >11,633,156</td>
#       <td id="T_f6824_row1_col8" class="data row1 col8" >Ene-Mar 2024</td>
#     </tr>
#     <tr>
#       <th id="T_f6824_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f6824_row2_col0" class="data row2 col0" >2,023</td>
#       <td id="T_f6824_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_f6824_row2_col2" class="data row2 col2" >836,390</td>
#       <td id="T_f6824_row2_col3" class="data row2 col3" >6,022,532</td>
#       <td id="T_f6824_row2_col4" class="data row2 col4" >3,908,183</td>
#       <td id="T_f6824_row2_col5" class="data row2 col5" >585,760</td>
#       <td id="T_f6824_row2_col6" class="data row2 col6" >194,796</td>
#       <td id="T_f6824_row2_col7" class="data row2 col7" >11,547,661</td>
#       <td id="T_f6824_row2_col8" class="data row2 col8" >Oct-Dic 2023</td>
#     </tr>
#     <tr>
#       <th id="T_f6824_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f6824_row3_col0" class="data row3 col0" >2,023</td>
#       <td id="T_f6824_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_f6824_row3_col2" class="data row3 col2" >897,895</td>
#       <td id="T_f6824_row3_col3" class="data row3 col3" >6,018,832</td>
#       <td id="T_f6824_row3_col4" class="data row3 col4" >3,708,718</td>
#       <td id="T_f6824_row3_col5" class="data row3 col5" >581,436</td>
#       <td id="T_f6824_row3_col6" class="data row3 col6" >200,027</td>
#       <td id="T_f6824_row3_col7" class="data row3 col7" >11,406,908</td>
#       <td id="T_f6824_row3_col8" class="data row3 col8" >Jul-Sept 2023</td>
#     </tr>
#     <tr>
#       <th id="T_f6824_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f6824_row4_col0" class="data row4 col0" >2,023</td>
#       <td id="T_f6824_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_f6824_row4_col2" class="data row4 col2" >1,006,509</td>
#       <td id="T_f6824_row4_col3" class="data row4 col3" >5,997,149</td>
#       <td id="T_f6824_row4_col4" class="data row4 col4" >3,463,988</td>
#       <td id="T_f6824_row4_col5" class="data row4 col5" >581,823</td>
#       <td id="T_f6824_row4_col6" class="data row4 col6" >202,428</td>
#       <td id="T_f6824_row4_col7" class="data row4 col7" >11,251,897</td>
#       <td id="T_f6824_row4_col8" class="data row4 col8" >Abr-Jun 2023</td>
#     </tr>
#     <tr>
#       <th id="T_f6824_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f6824_row5_col0" class="data row5 col0" >2,023</td>
#       <td id="T_f6824_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_f6824_row5_col2" class="data row5 col2" >1,204,417</td>
#       <td id="T_f6824_row5_col3" class="data row5 col3" >6,002,582</td>
#       <td id="T_f6824_row5_col4" class="data row5 col4" >3,243,411</td>
#       <td id="T_f6824_row5_col5" class="data row5 col5" >576,647</td>
#       <td id="T_f6824_row5_col6" class="data row5 col6" >214,838</td>
#       <td id="T_f6824_row5_col7" class="data row5 col7" >11,241,895</td>
#       <td id="T_f6824_row5_col8" class="data row5 col8" >Ene-Mar 2023</td>
#     </tr>
#     <tr>
#       <th id="T_f6824_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f6824_row6_col0" class="data row6 col0" >2,022</td>
#       <td id="T_f6824_row6_col1" class="data row6 col1" >4</td>
#       <td id="T_f6824_row6_col2" class="data row6 col2" >1,315,373</td>
#       <td id="T_f6824_row6_col3" class="data row6 col3" >6,037,457</td>
#       <td id="T_f6824_row6_col4" class="data row6 col4" >3,060,575</td>
#       <td id="T_f6824_row6_col5" class="data row6 col5" >572,969</td>
#       <td id="T_f6824_row6_col6" class="data row6 col6" >221,740</td>
#       <td id="T_f6824_row6_col7" class="data row6 col7" >11,208,114</td>
#       <td id="T_f6824_row6_col8" class="data row6 col8" >Oct-Dic 2022</td>
#     </tr>
#     <tr>
#       <th id="T_f6824_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f6824_row7_col0" class="data row7 col0" >2,022</td>
#       <td id="T_f6824_row7_col1" class="data row7 col1" >3</td>
#       <td id="T_f6824_row7_col2" class="data row7 col2" >1,395,277</td>
#       <td id="T_f6824_row7_col3" class="data row7 col3" >6,031,970</td>
#       <td id="T_f6824_row7_col4" class="data row7 col4" >2,871,541</td>
#       <td id="T_f6824_row7_col5" class="data row7 col5" >557,110</td>
#       <td id="T_f6824_row7_col6" class="data row7 col6" >235,230</td>
#       <td id="T_f6824_row7_col7" class="data row7 col7" >11,091,128</td>
#       <td id="T_f6824_row7_col8" class="data row7 col8" >Jul-Sept 2022</td>
#     </tr>
#     <tr>
#       <th id="T_f6824_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f6824_row8_col0" class="data row8 col0" >2,022</td>
#       <td id="T_f6824_row8_col1" class="data row8 col1" >2</td>
#       <td id="T_f6824_row8_col2" class="data row8 col2" >1,468,333</td>
#       <td id="T_f6824_row8_col3" class="data row8 col3" >5,979,214</td>
#       <td id="T_f6824_row8_col4" class="data row8 col4" >2,723,285</td>
#       <td id="T_f6824_row8_col5" class="data row8 col5" >556,243</td>
#       <td id="T_f6824_row8_col6" class="data row8 col6" >231,609</td>
#       <td id="T_f6824_row8_col7" class="data row8 col7" >10,958,684</td>
#       <td id="T_f6824_row8_col8" class="data row8 col8" >Abr-Jun 2022</td>
#     </tr>
#     <tr>
#       <th id="T_f6824_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f6824_row9_col0" class="data row9 col0" >2,022</td>
#       <td id="T_f6824_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_f6824_row9_col2" class="data row9 col2" >1,533,240</td>
#       <td id="T_f6824_row9_col3" class="data row9 col3" >6,073,426</td>
#       <td id="T_f6824_row9_col4" class="data row9 col4" >2,219,533</td>
#       <td id="T_f6824_row9_col5" class="data row9 col5" >545,814</td>
#       <td id="T_f6824_row9_col6" class="data row9 col6" >

# %% [markdown]
# ## 2. Handling missing values

# %% [markdown]
# ### Look for missing values in all cells

# %%
#Find missing values
df.isnull().sum()
# Out:
# Año             0
# Trimestre       0
# ADSL            0
# Cablemodem      0
# Fibra óptica    0
# Wireless        0
# Otros           0
# Total           0
# Periodo         0
# dtype: int64

# %% [markdown]
# #### There's no missing values

# %% [markdown]
# ## 3. Look for Duplicates

# %% [markdown]
# ### Find duplicates for complete rows

# %%
#Find duplicates by complete row
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### There's no complete duplicated rows

# %% [markdown]
# ### Fin duplicated rows for year and quarter ('Trimestre')

# %%
#Find duplicated rows by row, for year and quarter
df.duplicated(subset=['Año', 'Trimestre']).sum()
# Out:
# 0

# %% [markdown]
# #### There's no duplicated rows for year and quarter

# %% [markdown]
# ## 4. Finding outliers

# %%
#Finding outliers
df.describe()
# Out:
#            Año  Trimestre         ADSL   Cablemodem  Fibra óptica   Wireless  \
# count    42.00      42.00        42.00        42.00         42.00      42.00
# mean  2,018.76       2.45 2,694,843.86 4,433,906.00  1,224,693.57 304,293.21
# std       3.07       1.13 1,094,346.63 1,319,783.05  1,321,135.97 203,202.40
# min   2,014.00       1.00   733,491.00 2,407,330.00    139,187.00  70,749.00
# 25%   2,016.00       1.25 1,730,869.00 3,146,291.75    171,941.00  85,390.50
# 50%   2,019.00       2.00 3,061,623.00 4,535,507.00    698,946.50 292,223.00
# 75%   2,021.00       3.00 3,713,297.50 5,857,192.25  1,945,689.00 515,434.00
# max   2,024.00       4.00 3,803,024.00 6,073,426.00  4,169,958.00 598,682.00
#
#            Otros         Total
# count      42.00         42.00
# mean  158,186.07  8,815,922.71
# std    82,363.51  1,733,188.75
# min    54,300.00  6,398,398.00
# 25%    70,430.00  7,218,130.75
# 50%   185,221.00  8,720,658.00
# 75%   244,069.50 10,388,730.75
# max   265,328.00 11,633,156.00

# %% [markdown]
# #### In the statistics, we can see there's no outliers values for the column year ("Año"), because the maximum value is 2024 and the data is historical. For the quarter ("Trimestre") column the minimum an maximum values are correct, 1 and 4. For the cuantitative columns ADSL, Cablemodem, Fibra Óptica, Wireless and others, the min and max values are consitent for the mean and standard deviation. No outlies detected.

# %%
df.groupby(['Año','Trimestre']).sum()
# Out:
#                    ADSL  Cablemodem  Fibra óptica  Wireless   Otros     Total  \
# Año  Trimestre
# 2014 1          3697066     2407330        150323     70749   72930   6398398
#      2          3708882     2461670        149363     72405   72148   6464468
#      3          3714764     2569868        155494     85096   70049   6595271
#      4          3764038     2536219        149682     76984   71573   6598496
# 2015 1          3756153     2668248        168188     79098   66045   6737732
#      2          3767821     2756294        150839     82077   59157   6816188
#      3          3788696     2840203        162663     84530   58976   6935068
#      4          3803024     2898226        139187     85726   58668   6984831
# 2016 1          3792493     2806359        164371     85370   58763   6907356
#      2          3782085     3035272        167788     85452   59482   7130079
#      3          3776442     3124855        169898     81455   54300   7206950
#      4          3722794     3210602        178070     85119   55088   7251673
# 2017 1          3708898     3276251        180146     84813   55746   7305854
#      2          3723518     3383434        180777     85813   56122   7429664
#      3          3622575     3670221        193964    106443  131740   7724943
#      4          3584311     3818157        211425    155775  100554   7870222
# 2018 1          3574294     3981129        217460    165300   98870   8037053
#      2          3557216     4038141        226285    194267   94535   8110444
#      3          3521447     4238171        247366    246181   93870   8347035
#      4          3329027     4313831        388013    264299  178485   8473655
# 2019 1          3132789     4435439        637099    276419  166389   8648135
#      2          2990457     4635575        760794    308027  265328   8960181
#      3          2909805     4800091        852221    338241  264326   9164684
#      4          2414575     4883869        941295    340144  213298   8793181
# 2020 1          2299457     4903674       1047817    352333  209145   8812426
#      2          2295533     5005115       1106725    376667  247016   9031056
#      3          2263889     5259351       1170879    413259  248821   9356199
#      4          2213949     5371824       1311199    421554  253036   9571562
# 2021 1          2175211     5424782       1362976    434548  250455   9647972
#      2          2018587     5641731       1472246    476968  253552   9863084
#      3          1950631     5826257       1566048    492415  250190  10085541
#      4          1657615     5984240       2072236    523107  252596  10489794
# 2022 1          1533240     6073426       2219533    545814  251996  10624009
#      2          1468333     5979214       2723285    556243  231609  10958684
#      3          1395277     6031970       2871541    557110  235230  11091128
#      4          1315373     6037457       3060575    572969  221740  11208114
# 2023 1          1204417     6002582       3243411    576647  214838  11241895
#      2          1006509     5997149       3463988    581823  202428  11251897
#      3           897895     6018832       3708718    581436  200027  11406908
#      4           836390     6022532       3908183    585760  194796  11547661
# 2024 1           774475     5986957       4015101    598682  257941  11633156
#      2           733491     5867504       4169958    593197  191957  11556107
#
#                       Periodo
# Año  Trimestre
# 2014 1           Ene-Mar 2014
#      2           Abr-Jun 2014
#      3          Jul-Sept 2014
#      4           Oct-Dic 2014
# 2015 1           Ene-Mar 2015
#      2           Abr-Jun 2015
#      3          Jul-Sept 2015
#      4           Oct-Dic 2015
# 2016 1           Ene-Mar 2016
#      2           Abr-Jun 2016
#      3          Jul-Sept 2016
#      4           Oct-Dic 2016
# 2017 1           Ene-Mar 2017
#      2           Abr-Jun 2017
#      3          Jul-Sept 2017
#      4           Oct-Dic 2017
# 2018 1           Ene-Mar 2018
#      2           Abr-Jun 2018
#      3          Jul-Sept 2018
#      4           Oct-Dic 2018
# 2019 1           Ene-Mar 2019
#      2           Abr-Jun 2019
#      3          Jul-Sept 2019
#      4           Oct-Dic 2019
# 2020 1           Ene-Mar 2020
#      2           Abr-Jun 2020
#      3          Jul-Sept 2020
#      4           Oct-Dic 2020
# 2021 1           Ene-Mar 2021
#      2           Abr-Jun 2021
#      3          Jul-Sept 2021
#      4           Oct-Dic 2021
# 2022 1           Ene-Mar 2022
#      2           Abr-Jun 2022
#      3          Jul-Sept 2022
#      4           Oct-Dic 2022
# 2023 1           Ene-Mar 2023
#      2           Abr-Jun 2023
#      3          Jul-Sept 2023
#      4           Oct-Dic 2023
# 2024 1           Ene-Mar 2024
#      2           Abr-Jun 2024

# %% [markdown]
# #### All pairs year-quarter are present, there's no missing data.

# %% [markdown]
# #### All columns have consistent growth or decrease patterns. The kind of pattern is given for the The oldness of the technologie, having a decrease patternt for the oldest (i.e. ADSL) and a growth one for the newest (i.e. Optical and Wireless ). This will be explored in detail in the EDA section.

# %% [markdown]
# ## 5. Data Types

# %% [markdown]
# ### We will review the data types for each column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Año           42 non-null     int64
#  1   Trimestre     42 non-null     int64
#  2   ADSL          42 non-null     int64
#  3   Cablemodem    42 non-null     int64
#  4   Fibra óptica  42 non-null     int64
#  5   Wireless      42 non-null     int64
#  6   Otros         42 non-null     int64
#  7   Total         42 non-null     int64
#  8   Periodo       42 non-null     object
# dtypes: int64(8), object(1)
# memory usage: 3.1+ KB

# %% [markdown]
# #### The data types are consistent with the data provided. Just the column "Periodo" have an object data type, and have strings values. We should change the data type to string, but since the data is redundant with the quarter ("Periodo") column, we will drop it.

# %%
#drop Periodo column
df = df.drop('Periodo', axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Año           42 non-null     int64
#  1   Trimestre     42 non-null     int64
#  2   ADSL          42 non-null     int64
#  3   Cablemodem    42 non-null     int64
#  4   Fibra óptica  42 non-null     int64
#  5   Wireless      42 non-null     int64
#  6   Otros         42 non-null     int64
#  7   Total         42 non-null     int64
# dtypes: int64(8)
# memory usage: 2.8 KB

# %% [markdown]
# ## New columns

# %% [markdown]
# ### Create a new column with the year and quarter

# %%
#Create a new column with the quarter and year
df['Periodo'] = (df['Año'].astype(str) + 'T' + df['Trimestre'].astype(str)).astype('string')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Año           42 non-null     int64
#  1   Trimestre     42 non-null     int64
#  2   ADSL          42 non-null     int64
#  3   Cablemodem    42 non-null     int64
#  4   Fibra óptica  42 non-null     int64
#  5   Wireless      42 non-null     int64
#  6   Otros         42 non-null     int64
#  7   Total         42 non-null     int64
#  8   Periodo       42 non-null     string
# dtypes: int64(8), string(1)
# memory usage: 3.1 KB

# %% [markdown]
# # Save dataset

# %%
df=df.reset_index()
df.to_parquet(ROOT_DIR + '/data_files/accesos_totales_tecnologia_clean.parquet')
