# %% [markdown]
# ## Load libraries

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
sys.path.append("../libs")
sys.path.append("../")
from definitions import ROOT_DIR
import utils as utils

# Set pandas options
# Not use scientific notation and use two decimal places and use comma as thousand separator
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # ETL

# %% [markdown]
# ## 1. Load dataset

# %%
# Load dataset from data_files/internet.xlsx - sheet: 'Ingresos '
df = utils.get_xls_sheet_data('/data_files/internet.xlsx', 'Penetración-poblacion')
df.head().style.format(thousands=',')
# Out:
# <style type="text/css">
# </style>
# <table id="T_3acfe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3acfe_level0_col0" class="col_heading level0 col0" >Año</th>
#       <th id="T_3acfe_level0_col1" class="col_heading level0 col1" >Trimestre</th>
#       <th id="T_3acfe_level0_col2" class="col_heading level0 col2" >Provincia</th>
#       <th id="T_3acfe_level0_col3" class="col_heading level0 col3" >Accesos por cada 100 hab</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3acfe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3acfe_row0_col0" class="data row0 col0" >2,023</td>
#       <td id="T_3acfe_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_3acfe_row0_col2" class="data row0 col2" >Buenos Aires</td>
#       <td id="T_3acfe_row0_col3" class="data row0 col3" >27.680000</td>
#     </tr>
#     <tr>
#       <th id="T_3acfe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3acfe_row1_col0" class="data row1 col0" >2,023</td>
#       <td id="T_3acfe_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_3acfe_row1_col2" class="data row1 col2" >Capital Federal</td>
#       <td id="T_3acfe_row1_col3" class="data row1 col3" >47.800000</td>
#     </tr>
#     <tr>
#       <th id="T_3acfe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3acfe_row2_col0" class="data row2 col0" >2,023</td>
#       <td id="T_3acfe_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_3acfe_row2_col2" class="data row2 col2" >Catamarca</td>
#       <td id="T_3acfe_row2_col3" class="data row2 col3" >17.460000</td>
#     </tr>
#     <tr>
#       <th id="T_3acfe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3acfe_row3_col0" class="data row3 col0" >2,023</td>
#       <td id="T_3acfe_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_3acfe_row3_col2" class="data row3 col2" >Chaco</td>
#       <td id="T_3acfe_row3_col3" class="data row3 col3" >11.850000</td>
#     </tr>
#     <tr>
#       <th id="T_3acfe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3acfe_row4_col0" class="data row4 col0" >2,023</td>
#       <td id="T_3acfe_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_3acfe_row4_col2" class="data row4 col2" >Chubut</td>
#       <td id="T_3acfe_row4_col3" class="data row4 col3" >26.040000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 2. Handling missing values

# %% [markdown]
# ### Look for missing values in all cells

# %%
#Find missing values
df.isnull().sum()
# Out:
# Año                         0
# Trimestre                   0
# Provincia                   0
# Accesos por cada 100 hab    0
# dtype: int64

# %% [markdown]
# #### There's no missing values

# %% [markdown]
# ## 3. Look for Duplicates

# %% [markdown]
# ### Find duplicates for complete rows

# %%
#Find duplicates by complete row
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### There's no complete duplicated rows

# %% [markdown]
# ### Fin duplicated rows for year and quarter ('Trimestre') and state ('Provincia')

# %%
#Find duplicated rows by row, for year and quarter
df.duplicated(subset=['Año', 'Trimestre', 'Provincia']).sum()
# Out:
# 0

# %% [markdown]
# #### There's no duplicated rows for year and quarter

# %% [markdown]
# ## 4. Finding outliers

# %%
#Finding outliers
df.describe()
# Out:
#            Año  Trimestre  Accesos por cada 100 hab
# count 1,000.00   1,000.00                  1,000.00
# mean  2,018.80       2.46                     15.73
# std       3.02       1.11                      9.24
# min   2,014.00       1.00                      2.72
# 25%   2,016.00       1.00                      9.02
# 50%   2,019.00       2.00                     13.67
# 75%   2,021.00       3.00                     20.32
# max   2,024.00       4.00                     52.24

# %% [markdown]
# #### In the statistics, we can see there's no outliers values for the column year ("Año"), because the maximum value is 2024 and the data is historical. For the quarter ("Trimestre") column the minimum an maximum values are correct, 1 and 4. For the "Accesos 100/hab" column the distance from max value are close to 75 percentile. No outliers where found.

# %%
df.groupby(['Año','Trimestre'])['Provincia'].agg(['count'])
# Out:
#                 count
# Año  Trimestre
# 2014 1             16
#      2             24
#      3             24
#      4             24
# 2015 1             24
#      2             24
#      3             24
#      4             24
# 2016 1             24
#      2             24
#      3             24
#      4             24
# 2017 1             24
#      2             24
#      3             24
#      4             24
# 2018 1             24
#      2             24
#      3             24
#      4             24
# 2019 1             24
#      2             24
#      3             24
#      4             24
# 2020 1             24
#      2             24
#      3             24
#      4             24
# 2021 1             24
#      2             24
#      3             24
#      4             24
# 2022 1             24
#      2             24
#      3             24
#      4             24
# 2023 1             24
#      2             24
#      3             24
#      4             24
# 2024 1             24
#      2             24

# %% [markdown]
# #### For the year 2014, 1st quarter ("Trimestre") we have 8 provinces without information:

# %%
df[(df['Año'] == 2014) & (df['Trimestre'] == 1)]
# Out:
#       Año  Trimestre        Provincia  Accesos por cada 100 hab
# 984  2014          1     Buenos Aires                     16.69
# 985  2014          1  Capital Federal                     42.66
# 986  2014          1        Catamarca                      6.18
# 987  2014          1            Chaco                      5.55
# 988  2014          1           Chubut                     12.70
# 989  2014          1          Córdoba                     16.13
# 990  2014          1       Corrientes                      5.89
# 991  2014          1       Entre Ríos                     10.30
# 992  2014          1          Formosa                      4.44
# 993  2014          1            Jujuy                      4.72
# 994  2014          1         La Pampa                     15.99
# 995  2014          1         La Rioja                      4.35
# 996  2014          1          Mendoza                      8.93
# 997  2014          1         Misiones                      6.32
# 998  2014          1          Neuquén                     14.88
# 999  2014          1        Río Negro                     13.87

# %% [markdown]
# #### The provinces without information are: ['Salta','San Juan', 'San Luis', 'Santa Cruz', 'Santa Fe', 'Santiago Del Estero', 'Tierra Del Fuego', 'Tucumán'] we will input 0 because the age of the lost values makes one think that there were no measurements even in that place.

# %%
lost_provinces = ['Salta','San Juan', 'San Luis', 'Santa Cruz', 'Santa Fe', 'Santiago Del Estero', 'Tierra Del Fuego', 'Tucumán']

for lost_province in lost_provinces:
  lost_df = df.head(1).copy()
  lost_df['Año'] = 2014
  lost_df['Trimestre'] = 1
  lost_df['Provincia'] = lost_province
  lost_df['Accesos por cada 100 hab'] = 0
  df=pd.concat([df, lost_df])

df=df.reset_index()
df[(df['Año'] == 2014) & (df['Trimestre'] == 1)]
# Out:
#       index   Año  Trimestre            Provincia  Accesos por cada 100 hab
# 984     984  2014          1         Buenos Aires                     16.69
# 985     985  2014          1      Capital Federal                     42.66
# 986     986  2014          1            Catamarca                      6.18
# 987     987  2014          1                Chaco                      5.55
# 988     988  2014          1               Chubut                     12.70
# 989     989  2014          1              Córdoba                     16.13
# 990     990  2014          1           Corrientes                      5.89
# 991     991  2014          1           Entre Ríos                     10.30
# 992     992  2014          1              Formosa                      4.44
# 993     993  2014          1                Jujuy                      4.72
# 994     994  2014          1             La Pampa                     15.99
# 995     995  2014          1             La Rioja                      4.35
# 996     996  2014          1              Mendoza                      8.93
# 997     997  2014          1             Misiones                      6.32
# 998     998  2014          1              Neuquén                     14.88
# 999     999  2014          1            Río Negro                     13.87
# 1000      0  2014          1                Salta                      0.00
# 1001      0  2014          1             San Juan                      0.00
# 1002      0  2014          1             San Luis                      0.00
# 1003      0  2014          1           Santa Cruz                      0.00
# 1004      0  2014          1             Santa Fe                      0.00
# 1005      0  2014          1  Santiago Del Estero                      0.00
# 1006      0  2014          1     Tierra Del Fuego                      0.00
# 1007      0  2014          1              Tucumán                      0.00

# %% [markdown]
# ## 5. Data Types

# %% [markdown]
# ### We will review the data types for each column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1008 entries, 0 to 1007
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     1008 non-null   int64
#  1   Año                       1008 non-null   int64
#  2   Trimestre                 1008 non-null   int64
#  3   Provincia                 1008 non-null   object
#  4   Accesos por cada 100 hab  1008 non-null   float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 39.5+ KB

# %% [markdown]
# #### The 'Provincia' column have an object data type, and have strings values. We should change the data type to string.

# %%
#Change provincia to string
df['Provincia'] = df['Provincia'].astype('string')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1008 entries, 0 to 1007
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     1008 non-null   int64
#  1   Año                       1008 non-null   int64
#  2   Trimestre                 1008 non-null   int64
#  3   Provincia                 1008 non-null   string
#  4   Accesos por cada 100 hab  1008 non-null   float64
# dtypes: float64(1), int64(3), string(1)
# memory usage: 39.5 KB

# %% [markdown]
# ## New columns

# %% [markdown]
# ### Create a new column with the year and quarter

# %%
#Create a new column with the quarter and year
df['Periodo'] = (df['Año'].astype(str) + 'T' + df['Trimestre'].astype(str)).astype('string')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1008 entries, 0 to 1007
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     1008 non-null   int64
#  1   Año                       1008 non-null   int64
#  2   Trimestre                 1008 non-null   int64
#  3   Provincia                 1008 non-null   string
#  4   Accesos por cada 100 hab  1008 non-null   float64
#  5   Periodo                   1008 non-null   string
# dtypes: float64(1), int64(3), string(2)
# memory usage: 47.4 KB

# %% [markdown]
# # Save dataset

# %%
df=df.reset_index()
df.to_parquet(ROOT_DIR + '/data_files/penetracion_poblacion_clean.parquet')
