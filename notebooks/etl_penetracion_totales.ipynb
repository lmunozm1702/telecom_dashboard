# %% [markdown]
# ## Load libraries

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
sys.path.append("../libs")
sys.path.append("../")
from definitions import ROOT_DIR
import utils as utils

# Set pandas options
# Not use scientific notation and use two decimal places and use comma as thousand separator
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # ETL

# %% [markdown]
# ## 1. Load dataset

# %%
# Load dataset from data_files/internet.xlsx - sheet: 'Ingresos '
df = utils.get_xls_sheet_data('/data_files/internet.xlsx', 'Penetracion-totales')
df.style.format(thousands=',')
# Out:
# <style type="text/css">
# </style>
# <table id="T_7d84b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d84b_level0_col0" class="col_heading level0 col0" >Año</th>
#       <th id="T_7d84b_level0_col1" class="col_heading level0 col1" >Trimestre</th>
#       <th id="T_7d84b_level0_col2" class="col_heading level0 col2" >Accesos por cada 100 hogares</th>
#       <th id="T_7d84b_level0_col3" class="col_heading level0 col3" >Accesos por cada 100 hab</th>
#       <th id="T_7d84b_level0_col4" class="col_heading level0 col4" >Periodo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d84b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d84b_row0_col0" class="data row0 col0" >2,024</td>
#       <td id="T_7d84b_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_7d84b_row0_col2" class="data row0 col2" >78.130000</td>
#       <td id="T_7d84b_row0_col3" class="data row0 col3" >24.570000</td>
#       <td id="T_7d84b_row0_col4" class="data row0 col4" >Abr-Jun 2024</td>
#     </tr>
#     <tr>
#       <th id="T_7d84b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7d84b_row1_col0" class="data row1 col0" >2,024</td>
#       <td id="T_7d84b_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_7d84b_row1_col2" class="data row1 col2" >78.890000</td>
#       <td id="T_7d84b_row1_col3" class="data row1 col3" >24.790000</td>
#       <td id="T_7d84b_row1_col4" class="data row1 col4" >Ene-Mar 2024</td>
#     </tr>
#     <tr>
#       <th id="T_7d84b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7d84b_row2_col0" class="data row2 col0" >2,023</td>
#       <td id="T_7d84b_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_7d84b_row2_col2" class="data row2 col2" >78.560000</td>
#       <td id="T_7d84b_row2_col3" class="data row2 col3" >24.660000</td>
#       <td id="T_7d84b_row2_col4" class="data row2 col4" >Oct-Dic 2023</td>
#     </tr>
#     <tr>
#       <th id="T_7d84b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7d84b_row3_col0" class="data row3 col0" >2,023</td>
#       <td id="T_7d84b_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_7d84b_row3_col2" class="data row3 col2" >77.840000</td>
#       <td id="T_7d84b_row3_col3" class="data row3 col3" >24.410000</td>
#       <td id="T_7d84b_row3_col4" class="data row3 col4" >Jul-Sept 2023</td>
#     </tr>
#     <tr>
#       <th id="T_7d84b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7d84b_row4_col0" class="data row4 col0" >2,023</td>
#       <td id="T_7d84b_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_7d84b_row4_col2" class="data row4 col2" >77.020000</td>
#       <td id="T_7d84b_row4_col3" class="data row4 col3" >24.140000</td>
#       <td id="T_7d84b_row4_col4" class="data row4 col4" >Abr-Jun 2023</td>
#     </tr>
#     <tr>
#       <th id="T_7d84b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7d84b_row5_col0" class="data row5 col0" >2,023</td>
#       <td id="T_7d84b_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_7d84b_row5_col2" class="data row5 col2" >77.200000</td>
#       <td id="T_7d84b_row5_col3" class="data row5 col3" >24.170000</td>
#       <td id="T_7d84b_row5_col4" class="data row5 col4" >Ene-Mar 2023</td>
#     </tr>
#     <tr>
#       <th id="T_7d84b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7d84b_row6_col0" class="data row6 col0" >2,022</td>
#       <td id="T_7d84b_row6_col1" class="data row6 col1" >4</td>
#       <td id="T_7d84b_row6_col2" class="data row6 col2" >77.210000</td>
#       <td id="T_7d84b_row6_col3" class="data row6 col3" >24.150000</td>
#       <td id="T_7d84b_row6_col4" class="data row6 col4" >Oct-Dic 2022</td>
#     </tr>
#     <tr>
#       <th id="T_7d84b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7d84b_row7_col0" class="data row7 col0" >2,022</td>
#       <td id="T_7d84b_row7_col1" class="data row7 col1" >3</td>
#       <td id="T_7d84b_row7_col2" class="data row7 col2" >76.640000</td>
#       <td id="T_7d84b_row7_col3" class="data row7 col3" >23.950000</td>
#       <td id="T_7d84b_row7_col4" class="data row7 col4" >Jul-Sept 2022</td>
#     </tr>
#     <tr>
#       <th id="T_7d84b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7d84b_row8_col0" class="data row8 col0" >2,022</td>
#       <td id="T_7d84b_row8_col1" class="data row8 col1" >2</td>
#       <td id="T_7d84b_row8_col2" class="data row8 col2" >75.965424</td>
#       <td id="T_7d84b_row8_col3" class="data row8 col3" >23.720442</td>
#       <td id="T_7d84b_row8_col4" class="data row8 col4" >Abr-Jun 2022</td>
#     </tr>
#     <tr>
#       <th id="T_7d84b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7d84b_row9_col0" class="data row9 col0" >2,022</td>
#       <td id="T_7d84b_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_7d84b_row9_col2" class="data row9 col2" >73.878803</td>
#       <td id="T_7d84b_row9_col3" class="data row9 col3" >23.049171</td>
#       <td id="T_7d84b_row9_col4" class="data row9 col4" >Ene-Mar 2022</td>
#     </tr>
#     <tr>
#       <th id="T_7d84b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7d84b_row10_col0" class="data row10 col0" >2,021</td>
#       <td id="T_7d84b_row10_col1" class="data row10 col1" >4</td>
#       <td id="T_7d84b_row10_col2" class="data row10 col2" >73.176397</td>
#       <td id="T_7d84b_row10_col3" class="data row10 col3" >22.810702</td>
#       <td id="T_7d84b_row10_col4" class="data row10 col4" >Oct-Dic 2021</td>
#     </tr>
#     <tr>
#       <th id="T_7d84b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7d84b_row11_col0" class="data row11 col0" >2,021</td>
#       <td id="T_7d84b_row11_col1" class="data row11 col1" >3</td>
#       <td id="T_7d84b_row11_col2" class="data row11 col2" >70.578853</td>
#       <td id="T_7d84b_row11_col3" class="data row11 col3" >21.982550</td>
#       <td id="T_7d84b_row11_col4" class="data row11 col4" >Jul-Sept 2021</td>
#     </tr>
#     <tr>
#       <th id="T_7d84b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7d84b_row12_col0" class="data row12 col0" >2,021</td>
#       <td id="T_7d84b_row12_col1" class="data row12 col1" >2</td>
#       <td id="T_7d84b_row12_col2" class="data row12 col2" >69.240183</td>
#       <td id="T_7d84b_row12_col3" class="data row12 col3" >21.547939</td>
#       <td id="T_7d84b_row12_col4" class="data row12 col4" >Abr-Jun 2021</td>
#     </tr>
#     <tr>
#       <th id="T_7d84b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7d84b_row13_col0" class="data row13 col0" >2,021</td>
#       <td id="T_7d84b_row13_col1" class="data row13 col1" >1</td>
#       <td id="T_7d84b_row13_col2" class="data row13 col2" >67.945876</td>
#       <td id="T_7d84b_row13_col3" class="data row13 col3" >21.127832</td>
#       <td id="T_7d84b_row13_col4" class="data row13 col4" >Ene-Mar 2021</td>
#     </tr>
#     <tr>
#       <th id="T_7d84b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7d84b_row14_col0" class="data row14 col0" >2,020</td>
#       <td id="T_7d84b_row14_col1" class="data row14 col1" >4</td>
#       <td id="T_7d84b_row14_col2" class="data row14 col2" >67.622339</td>
#       <td id="T_7d84b_row14_col3" class="data row14 col3" >21.010192</td>
#       <td id="T_7d84b_row14_col4" class="data row14 col4" >Oct-Dic 2020</td>
#     </tr>
#     <tr>
#       <th id="T_7d84b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7d84b_row15_col0" class="data row15 col0" >2,020</td>
#       <td id="T_7d84b_row15_col1" class="data row15 col1" >3</td>
#       <td id="T_7d84b_row15_col2" class="data row15 col2" >66.310000</td>
#       <td id="T_7d84b_row15_col3" class="data row15 col3" >20.590000</td>
#       <td id="T_7d84b_row15_col4" class="data row15 col4" >Jul-Sept 2020</td>
#     </tr>
#     <tr>
#       <th id="T_7d84b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7d84b_row16_col0" class="data row16 col0" >2,020</td>
#       <td id="T_7d84b_row16_col1" class="data row16

# %% [markdown]
# ## 2. Handling missing values

# %% [markdown]
# ### Look for missing values in all cells

# %%
#Find missing values
df.isnull().sum()
# Out:
# Año                             0
# Trimestre                       0
# Accesos por cada 100 hogares    0
# Accesos por cada 100 hab        0
# Periodo                         0
# dtype: int64

# %% [markdown]
# #### There's no missing values

# %% [markdown]
# ## 3. Look for Duplicates

# %% [markdown]
# ### Find duplicates for complete rows

# %%
#Find duplicates by complete row
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### There's no complete duplicated rows

# %% [markdown]
# ### Fin duplicated rows for year and quarter ('Trimestre')

# %%
#Find duplicated rows by row, for year and quarter
df.duplicated(subset=['Año', 'Trimestre']).sum()
# Out:
# 0

# %% [markdown]
# #### There's no duplicated rows for year and quarter

# %% [markdown]
# ## 4. Finding outliers

# %%
#Finding outliers
df.describe()
# Out:
#            Año  Trimestre  Accesos por cada 100 hogares  \
# count    42.00      42.00                         42.00
# mean  2,018.76       2.45                         63.20
# std       3.07       1.13                          9.95
# min   2,014.00       1.00                         49.55
# 25%   2,016.00       1.25                         53.78
# 50%   2,019.00       2.00                         62.67
# 75%   2,021.00       3.00                         72.53
# max   2,024.00       4.00                         78.89
#
#        Accesos por cada 100 hab
# count                     42.00
# mean                      19.57
# std                        3.27
# min                       15.05
# 25%                       16.52
# 50%                       19.40
# 75%                       22.60
# max                       24.79

# %% [markdown]
# #### In the statistics, we can see there's no outliers values for the column year ("Año"), because the maximum value is 2024 and the data is historical. For the quarter ("Trimestre") column the minimum an maximum values are correct, 1 and 4. For the cuantitative columns Accesos por cada 100 hogares and Accesos por cada 100 habitantes, the min and max values are consitent for the mean and standard deviation. No outlies detected.

# %%
df.groupby(['Año','Trimestre']).sum()
# Out:
#                 Accesos por cada 100 hogares  Accesos por cada 100 hab  \
# Año  Trimestre
# 2014 1                                 49.55                     15.05
#      2                                 49.86                     15.16
#      3                                 50.67                     15.43
#      4                                 50.50                     15.39
# 2015 1                                 51.36                     15.68
#      2                                 51.76                     15.82
#      3                                 52.46                     16.05
#      4                                 52.63                     16.12
# 2016 1                                 51.85                     15.90
#      2                                 53.34                     16.37
#      3                                 53.73                     16.50
#      4                                 53.94                     16.56
# 2017 1                                 54.16                     16.64
#      2                                 54.90                     16.88
#      3                                 56.90                     17.51
#      4                                 57.78                     17.79
# 2018 1                                 58.82                     18.12
#      2                                 59.16                     18.24
#      3                                 60.69                     18.73
#      4                                 61.42                     18.97
# 2019 1                                 62.48                     19.31
#      2                                 64.53                     19.96
#      3                                 65.79                     20.36
#      4                                 62.92                     19.49
# 2020 1                                 62.86                     19.48
#      2                                 64.21                     19.92
#      3                                 66.31                     20.59
#      4                                 67.62                     21.01
# 2021 1                                 67.95                     21.13
#      2                                 69.24                     21.55
#      3                                 70.58                     21.98
#      4                                 73.18                     22.81
# 2022 1                                 73.88                     23.05
#      2                                 75.97                     23.72
#      3                                 76.64                     23.95
#      4                                 77.21                     24.15
# 2023 1                                 77.20                     24.17
#      2                                 77.02                     24.14
#      3                                 77.84                     24.41
#      4                                 78.56                     24.66
# 2024 1                                 78.89                     24.79
#      2                                 78.13                     24.57
#
#                       Periodo
# Año  Trimestre
# 2014 1           Ene-Mar 2014
#      2           Abr-Jun 2014
#      3          Jul-Sept 2014
#      4           Oct-Dic 2014
# 2015 1           Ene-Mar 2015
#      2           Abr-Jun 2015
#      3          Jul-Sept 2015
#      4           Oct-Dic 2015
# 2016 1           Ene-Mar 2016
#      2           Abr-Jun 2016
#      3          Jul-Sept 2016
#      4           Oct-Dic 2016
# 2017 1           Ene-Mar 2017
#      2           Abr-Jun 2017
#      3          Jul-Sept 2017
#      4           Oct-Dic 2017
# 2018 1           Ene-Mar 2018
#      2           Abr-Jun 2018
#      3          Jul-Sept 2018
#      4           Oct-Dic 2018
# 2019 1           Ene-Mar 2019
#      2           Abr-Jun 2019
#      3          Jul-Sept 2019
#      4           Oct-Dic 2019
# 2020 1           Ene-Mar 2020
#      2           Abr-Jun 2020
#      3          Jul-Sept 2020
#      4           Oct-Dic 2020
# 2021 1           Ene-Mar 2021
#      2           Abr-Jun 2021
#      3          Jul-Sept 2021
#      4           Oct-Dic 2021
# 2022 1           Ene-Mar 2022
#      2           Abr-Jun 2022
#      3          Jul-Sept 2022
#      4           Oct-Dic 2022
# 2023 1           Ene-Mar 2023
#      2           Abr-Jun 2023
#      3          Jul-Sept 2023
#      4           Oct-Dic 2023
# 2024 1           Ene-Mar 2024
#      2           Abr-Jun 2024

# %% [markdown]
# #### All pairs year-quarter are present, there's no missing data.

# %% [markdown]
# #### All columns have consistent growth pattern. This will be explored in detail in the EDA section. The growth patter is not consistent with the expotential behaviour of incomes dataset, that reafirm the hipotesys that the incomes behaivour is given by inflation and devaluations.

# %% [markdown]
# ## 5. Data Types

# %% [markdown]
# ### We will review the data types for each column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Año                           42 non-null     int64
#  1   Trimestre                     42 non-null     int64
#  2   Accesos por cada 100 hogares  42 non-null     float64
#  3   Accesos por cada 100 hab      42 non-null     float64
#  4   Periodo                       42 non-null     object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 1.8+ KB

# %% [markdown]
# #### The data types are consistent with the data provided. Just the column "Periodo" have an object data type, and have strings values. We should change the data type to string, but since the data is redundant with the quarter ("Periodo") column, we will drop it.

# %%
#drop Periodo column
df = df.drop('Periodo', axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Año                           42 non-null     int64
#  1   Trimestre                     42 non-null     int64
#  2   Accesos por cada 100 hogares  42 non-null     float64
#  3   Accesos por cada 100 hab      42 non-null     float64
# dtypes: float64(2), int64(2)
# memory usage: 1.4 KB

# %% [markdown]
# ## New columns

# %% [markdown]
# ### Create a new column with the year and quarter

# %%
#Create a new column with the quarter and year
df['Periodo'] = (df['Año'].astype(str) + 'T' + df['Trimestre'].astype(str)).astype('string')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Año                           42 non-null     int64
#  1   Trimestre                     42 non-null     int64
#  2   Accesos por cada 100 hogares  42 non-null     float64
#  3   Accesos por cada 100 hab      42 non-null     float64
#  4   Periodo                       42 non-null     string
# dtypes: float64(2), int64(2), string(1)
# memory usage: 1.8 KB

# %% [markdown]
# # Save dataset

# %%
df.to_parquet(ROOT_DIR + '/data_files/penetracion_totales_clean.parquet')
